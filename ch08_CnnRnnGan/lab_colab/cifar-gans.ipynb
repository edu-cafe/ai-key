# %%
import keras
keras.__version__

# !rm -rf gan_images
# !rm -f gan.h5
# !rm -f soo_gan_generator.h5
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %% [markdown]
# ## GAN 구현 방법
#
# 이 절에서는 케라스에서 가장 기본적인 형태의 GAN을 구현하는 방법을 설명하겠습니다. GAN은 수준 높은 기술이기 때문에 기술적인 내용을 깊이 설명하는 것은 이 책의 범위를 벗어납니다. 구체적인 구현은 심층 합성곱 GAN(DCGAN)입니다. 생성자와 판별자가 심층 컨브넷입니다. 특히 생성자에서 이미지 업샘플링을 위해 `Conv2DTranspose` 층을 사용합니다.
#
# CIFAR10 데이터셋의 이미지로 GAN을 훈련하겠습니다. 이 데이터셋은 32 × 32 크기의 RGB 이미지 50,000개로 이루어져 있고 10개의 클래스를 가집니다(클래스마다 5,000개의 이미지가 있습니다). 문제를 간단하게 만들기 위해 “frog” 클래스의 이미지만 사용하겠습니다.
#
# GAN 구조는 다음과 같습니다:
#
# 1.	`generator` 네트워크는 `(latent_dim,)` 크기의 벡터를 `(32, 32, 3)` 크기의 이미지로 매핑합니다.
# 2.	`discriminator` 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진 값으로 매핑합니다.
# 3.	생성자와 판별자를 연결하는 `gan` 네트워크를 만듭니다. `gan(x) = discriminator(generator(x))` 입니다. 이 `gan` 네트워크는 잠재 공간의 벡터를 판별자의 평가로 매핑합니다. 판별자는 생성자가 잠재 공간의 벡터를 디코딩한 것이 얼마나 현실적인지를 평가합니다.
# 4.	“진짜"/”가짜" 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용해 판별자를 훈련합니다. 일반적인 이미지 분류 모델을 훈련하는 것과 동일합니다.
# 5. 생성자를 훈련하려면 `gan` 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용합니다. 이 말은 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 “진짜"로 분류하도록 만드는 방향으로 생성자의 가중치를 이동한다는 뜻입니다. 다른 말로하면 판별자를 속이도록 생성자를 훈련합니다.

# %% [markdown]
# ## 훈련 방법
#
# GAN을 훈련하고 튜닝하는 과정은 어렵기로 유명합니다. 알아두어야 할 몇 가지 유용한 기법이 있습니다. 딥러닝의 대부분이 그렇듯이 이는 과학보다는 연금술에 가깝습니다. 이런 기법들은 이론에 바탕을 둔 지침이 아니고 경험을 통해 발견된 것입니다. 실제 일어난 현상을 직관적으로 이해하는 수준에서 검증되었습니다. 모든 문제에 반드시 적용해야 것은 아니지만 경험상 잘 작동한다고 알려져 있습니다.
#
# 다음은 이 절에서 GAN 생성자와 판별자를 구현하는 데 사용할 몇 가지 기법입니다. 이 목록이 GAN에 관련된 전체 팁이 아닙니다. GAN 논문들에서 더 많은 방법을 볼 수 있습니다.
#
# * 생성자의 마지막 활성화로 다른 종류의 모델에서 널리 사용하는 `sigmoid` 대신 `tanh` 함수를 사용합니다.
# * 균등 분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링합니다.
# * 무작위성은 모델을 견고하게 만듭니다. GAN 훈련은 동적 평형을 만들기 때문에 여러 방식으로 갇힐 가능성이 높습니다. 훈련하는 동안 무작위성을 주입하면 이를 방지하는 데 도움이 됩니다. 무작위성은 두 가지 방법으로 주입합니다. 판별자에 드롭아웃을 사용하거나 판별자를 위해 레이블에 랜덤 노이즈를 추가합니다.
# * 희소한 그래디언트는 GAN 훈련을 방해할 수 있습니다. 딥러닝에서 희소는 종종 바람직한 현상이지만 GAN에서는 그렇지 않습니다. 그래디언트를 희소하게 만들 수 있는 것은 최대 풀링 연산과 ReLU 활성화 두 가지입니다. 최대 풀링 대신 스트라이드 합성곱을 사용해 다운샘플링을 하는 것이 좋습니다. 또 ReLU 활성화 대신 `LeakyReLU` 층을 사용하세요. ReLU와 비슷하지만 음수의 활성화 값을 조금 허용하기 때문에 희소가 조금 완화됩니다.
# * 생성자에서 픽셀 공간을 균일하게 다루지 못해 생성된 이미지에서 체스판 모양이 종종 나타납니다. 이를 해결하기 위해 생성자와 판별자에서 스트라이드 `Conv2DTranpose`나 `Conv2D`를 사용할 때 스트라이드 크기로 나누어질 수 있는 커널 크기를 사용합니다.

# %% [markdown]
# ## 생성자
#
# 먼저 벡터(훈련하는 동안 잠재 공간에서 무작위로 샘플링됩니다)를 후보 이미지로 변환하는 `generator` 모델을 만들어 보죠. GAN에서 발생하는 많은 문제 중 하나는 생성자가 노이즈 같은 이미지를 생성하는 데서 멈추는 것입니다. 판별자와 생성자 양쪽에 모두 드롭아웃을 사용하는 것이 해결 방법이 될 수 있습니다.

# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# 입력을 16 × 16 크기의 128개 채널을 가진 특성 맵으로 변환합니다
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# 합성곱 층을 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기로 업샘플링합니다
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# 합성곱 층을 더 추가합니다
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# 32 × 32 크기의 1개 채널을 가진 특성 맵을 생성합니다
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32768)             0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 판별자
#
# 다음은 후보 이미지(진짜 혹은 가짜)를 입력으로 받고 두 개의 클래스로 분류하는 `discriminator` 모델을 만들겠습니다. 이 클래스는 '생성된 이미지' 또는 '훈련 세트에서 온 진짜 이미지'입니다.

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# 드롭아웃 층을 넣는 것이 아주 중요합니다!
x = layers.Dropout(0.4)(x)

# 분류 층
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# 옵티마이저에서 (값을 지정하여) 그래디언트 클리핑을 사용합니다
# 안정된 훈련을 위해서 학습률 감쇠를 사용합니다
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 적대적 네트워크
#
# 마지막으로 생성자와 판별자를 연결하여 GAN을 설정합니다. 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습합니다. 이 모델은 잠재 공간의 포인트를 “진짜" 또는 “가짜"의 분류 결정으로 변환합니다. 훈련에 사용되는 타깃 레이블은 항상 '진짜 이미지'입니다. `gan`을 훈련하는 것은 `discriminator`가 가짜 이미지를 보았을 때 진짜라고 예측하도록 만들기 위해 `generator`의 가중치를 업데이트하는 것입니다. 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 아주 중요합니다. `gan`을 훈련할 때 가중치가 업데이트되지 않습니다. 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 “진짜"를 예측하도록 훈련됩니다. 이것이 우리가 원하는 바는 아니죠!

# %%
# 판별자의 가중치가 훈련되지 않도록 설정합니다(gan 모델에만 적용됩니다)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ## DCGAN 훈련 방법
#
# 이제 훈련을 시작합니다.  훈련 반복의 내용을 요약 정리해 보겠습니다.
#
# ```
# 매 반복마다 다음을 수행합니다:
#
#     1.잠재 공간에서 무작위로 포인트를 뽑습니다(랜덤 노이즈).
#     2.이 랜덤 노이즈를 사용해 `generator`에서 이미지를 생성합니다.
#     3.생성된 이미지와 진짜 이미지를 섞습니다.
#     4.진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용해 `discriminator`를 훈련합니다. 타깃은 “진짜"(실제 이미지일 경우) 또는 “가짜"(생성된 이미지일 경우)입니다.
#     5.잠재 공간에서 무작위로 새로운 포인트를 뽑습니다.
#     6.이 랜덤 벡터를 사용해 `gan`을 훈련합니다. 모든 타깃은 “진짜"로 설정합니다. 판별자가 생성된 이미지를 모두 “진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트합니다(`gan` 안에서 판별자는 동결되기 때문에 생성자만 업데이트합니다). 결국 생성자는 판별자를 속이도록 훈련합니다.
# ```
#
# 실제로 만들어 보죠:

# %%
import os
from keras.preprocessing import image

# CIFAR10 데이터를 로드합니다
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# 개구리 이미지를 선택합니다(클래스 6)
x_train = x_train[y_train.flatten() == 6]

# 데이터를 정규화합니다
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 20000
batch_size = 20
save_dir = './gan_images/'
if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# 훈련 반복 시작
start = 0
for step in range(iterations):
    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 가짜 이미지를 디코딩합니다
    generated_images = generator.predict(random_latent_vectors)

    # 진짜 이미지와 연결합니다
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # 진짜와 가짜 이미지를 구분하여 레이블을 합칩니다
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # 레이블에 랜덤 노이즈를 추가합니다. 아주 중요합니다!
    labels += 0.05 * np.random.random(labels.shape)

    # discriminator를 훈련합니다
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # 잠재 공간에서 무작위로 포인트를 샘플링합니다
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # 모두 “진짜 이미지"라고 레이블을 만듭니다
    misleading_targets = np.zeros((batch_size, 1))

    # generator를 훈련합니다(gan 모델에서 discriminator의 가중치는 동결됩니다)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # 중간 중간 저장하고 그래프를 그립니다
    if step % 100 == 0:
        # 모델 가중치를 저장합니다
        gan.save_weights('gan.h5')

        # 측정 지표를 출력합니다
        print('스텝 %s에서 판별자 손실: %s' % (step, d_loss))
        print('스텝 %s에서 적대적 손실: %s' % (step, a_loss))

        # 생성된 이미지 하나를 저장합니다
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # 비교를 위해 진짜 이미지 하나를 저장합니다
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 스텝 0에서 판별자 손실: 0.68461454
# 스텝 0에서 적대적 손실: 0.6702939
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 스텝 100에서 판별자 손실: 0.67351705
# 스텝 100에서 적대적 손실: 0.9224409
# 스텝 200에서 판별자 손실: 0.6890422
# 스텝 200에서 적대적 손실: 0.709229
# 스텝 300에서 판별자 손실: 0.68620634
# 스텝 300에서 적대적 손실: 0.78295887
# 스텝 400에서 판별자 손실: 0.6920215
# 스텝 400에서 적대적 손실: 0.7684605
# 스텝 500에서 판별자 손실: 0.6970566
# 스텝 500에서 적대적 손실: 0.76372176
# 스텝 600에서 판별자 손실: 0.6878692
# 스텝 600에서 적대적 손실: 0.7423299
# 스텝 700에서 판별자 손실: 0.6854762
# 스텝 700에서 적대적 손실: 0.8548859
# 스텝 800에서 판별자 손실: 0.6817994
# 스텝 800에서 적대적 손실: 0.8058073
# 스텝 900에서 판별자 손실: 0.6968826
# 스텝 900에서 적대적 손실: 0.746643
# 스텝 1000에서 판별자 손실: 0.7426823
# 스텝 1000에서 적대적 손실: 0.88081396
# 스텝 1100에서 판별자 손실: 0.77485543
# 스텝 1100에서 적대적 손실: 0.7343436
# 스텝 1200에서 판별자 손실: 0.6913185
# 스텝 1200에서 적대적 손실: 0.740094
# 스텝 1300에서 판별자 손실: 0.6823801
# 스텝 1300에서 적대적 손실: 0.7752706
# 스텝 1400에서 판별자 손실: 0.6988398
# 스텝 1400에서 적대적 손실: 0.74045503
# 스텝 1500에서 판별자 손실: 0.6884738
# 스텝 1500에서 적대적 손실: 0.75799805
# 스텝 1600에서 판별자 손실: 0.6988252
# 스텝 1600에서 적대적 손실: 0.74956334
# 스텝 1700에서 판별자 손실: 0.7035845
# 스텝 1700에서 적대적 손실: 0.8246075
# 스텝 1800에서 판별자 손실: 0.7083676
# 스텝 1800에서 적대적 손실: 0.7502988
# 스텝 1900에서 판별자 손실: 0.6905168
# 스텝 1900에서 적대적 손실: 0.7568997
# 스텝 2000에서 판별자 손실: 0.6976391
# 스텝 2000에서 적대적 손실: 0.74864674
# 스텝 2100에서 판별자 손실: 0.6794884
# 스텝 2100에서 적대적 손실: 0.73694694
# 스텝 2200에서 판별자 손실: 0.693289
# 스텝 2200에서 적대적 손실: 0.774077
# 스텝 2300에서 판별자 손실: 0.6999501
# 스텝 2300에서 적대적 손실: 0.7349049
# 스텝 2400에서 판별자 손실: 0.7194358
# 스텝 2400에서 적대적 손실: 0.7620395
# 스텝 2500에서 판별자 손실: 0.70556366
# 스텝 2500에서 적대적 손실: 0.7578434
# 스텝 2600에서 판별자 손실: 0.6960451
# 스텝 2600에서 적대적 손실: 0.73293096
# 스텝 2700에서 판별자 손실: 0.6835697
# 스텝 2700에서 적대적 손실: 0.74995357
# 스텝 2800에서 판별자 손실: 0.70325947
# 스텝 2800에서 적대적 손실: 0.7862356
# 스텝 2900에서 판별자 손실: 0.67656094
# 스텝 2900에서 적대적 손실: 0.7530414
# 스텝 3000에서 판별자 손실: 0.6958205
# 스텝 3000에서 적대적 손실: 0.7455341
# 스텝 3100에서 판별자 손실: 0.68979204
# 스텝 3100에서 적대적 손실: 0.7835795
# 스텝 3200에서 판별자 손실: 0.6916102
# 스텝 3200에서 적대적 손실: 0.7756066
# 스텝 3300에서 판별자 손실: 0.69573337
# 스텝 3300에서 적대적 손실: 0.7152797
# 스텝 3400에서 판별자 손실: 0.68697214
# 스텝 3400에서 적대적 손실: 0.77083033
# 스텝 3500에서 판별자 손실: 0.6912457
# 스텝 3500에서 적대적 손실: 0.7339205
# 스텝 3600에서 판별자 손실: 0.70232147
# 스텝 3600에서 적대적 손실: 0.76810414
# 스텝 3700에서 판별자 손실: 0.69401586
# 스텝 3700에서 적대적 손실: 0.759605
# 스텝 3800에서 판별자 손실: 0.7102429
# 스텝 3800에서 적대적 손실: 0.75757957
# 스텝 3900에서 판별자 손실: 0.7024233
# 스텝 3900에서 적대적 손실: 0.7319558
# 스텝 4000에서 판별자 손실: 0.6929079
# 스텝 4000에서 적대적 손실: 0.749119
# 스텝 4100에서 판별자 손실: 0.7118128
# 스텝 4100에서 적대적 손실: 0.7502438
# 스텝 4200에서 판별자 손실: 0.6820676
# 스텝 4200에서 적대적 손실: 0.78731906
# 스텝 4300에서 판별자 손실: 0.7439724
# 스텝 4300에서 적대적 손실: 0.68703496
# 스텝 4400에서 판별자 손실: 0.70797825
# 스텝 4400에서 적대적 손실: 0.7343
# 스텝 4500에서 판별자 손실: 0.6871976
# 스텝 4500에서 적대적 손실: 0.72327864
# 스텝 4600에서 판별자 손실: 0.6972418
# 스텝 4600에서 적대적 손실: 0.755325
# 스텝 4700에서 판별자 손실: 0.6905343
# 스텝 4700에서 적대적 손실: 0.9319876
# 스텝 4800에서 판별자 손실: 0.6976335
# 스텝 4800에서 적대적 손실: 0.80085117
# 스텝 4900에서 판별자 손실: 0.68561685
# 스텝 4900에서 적대적 손실: 0.76646453
# 스텝 5000에서 판별자 손실: 0.7100698
# 스텝 5000에서 적대적 손실: 0.72956616
# 스텝 5100에서 판별자 손실: 0.6951687
# 스텝 5100에서 적대적 손실: 0.8368
# 스텝 5200에서 판별자 손실: 0.6830078
# 스텝 5200에서 적대적 손실: 0.7437844
# 스텝 5300에서 판별자 손실: 0.70479286
# 스텝 5300에서 적대적 손실: 0.8182686
# 스텝 5400에서 판별자 손실: 0.69932806
# 스텝 5400에서 적대적 손실: 0.7351419
# 스텝 5500에서 판별자 손실: 0.6976425
# 스텝 5500에서 적대적 손실: 0.72961694
# 스텝 5600에서 판별자 손실: 0.70539916
# 스텝 5600에서 적대적 손실: 0.8924513
# 스텝 5700에서 판별자 손실: 0.7074691
# 스텝 5700에서 적대적 손실: 0.7946781
# 스텝 5800에서 판별자 손실: 0.68878967
# 스텝 5800에서 적대적 손실: 0.7792062
# 스텝 5900에서 판별자 손실: 0.6972567
# 스텝 5900에서 적대적 손실: 0.7185643
# 스텝 6000에서 판별자 손실: 0.6978131
# 스텝 6000에서 적대적 손실: 0.80974066
# 스텝 6100에서 판별자 손실: 0.6949969
# 스텝 6100에서 적대적 손실: 0.7855127
# 스텝 6200에서 판별자 손실: 0.76865053
# 스텝 6200에서 적대적 손실: 0.80360985
# 스텝 6300에서 판별자 손실: 0.6710304
# 스텝 6300에서 적대적 손실: 1.2938255
# 스텝 6400에서 판별자 손실: 0.6842042
# 스텝 6400에서 적대적 손실: 0.8409177
# 스텝 6500에서 판별자 손실: 0.7143118
# 스텝 6500에서 적대적 손실: 0.8419943
# 스텝 6600에서 판별자 손실: 0.7728163
# 스텝 6600에서 적대적 손실: 0.76895267
# 스텝 6700에서 판별자 손실: 0.7060439
# 스텝 6700에서 적대적 손실: 0.75163144
# 스텝 6800에서 판별자 손실: 0.6727938
# 스텝 6800에서 적대적 손실: 0.7873317
# 스텝 6900에서 판별자 손실: 0.6851222
# 스텝 6900에서 적대적 손실: 0.80399644
# 스텝 7000에서 판별자 손실: 0.66340333
# 스텝 7000에서 적대적 손실: 0.7883394
# 스텝 7100에서 판별자 손실: 0.68797576
# 스텝 7100에서 적대적 손실: 0.7162262
# 스텝 7200에서 판별자 손실: 0.73134136
# 스텝 7200에서 적대적 손실: 0.8241221
# 스텝 7300에서 판별자 손실: 0.696226
# 스텝 7300에서 적대적 손실: 0.7400002
# 스텝 7400에서 판별자 손실: 0.6870413
# 스텝 7400에서 적대적 손실: 0.80533856
# 스텝 7500에서 판별자 손실: 0.66320235
# 스텝 7500에서 적대적 손실: 0.9173505
# 스텝 7600에서 판별자 손실: 0.67496747
# 스텝 7600에서 적대적 손실: 0.80696976
# 스텝 7700에서 판별자 손실: 0.695802
# 스텝 7700에서 적대적 손실: 0.7815591
# 스텝 7800에서 판별자 손실: 0.72186726
# 스텝 7800에서 적대적 손실: 0.9462789
# 스텝 7900에서 판별자 손실: 0.6831514
# 스텝 7900에서 적대적 손실: 0.66698456
# 스텝 8000에서 판별자 손실: 0.71341103
# 스텝 8000에서 적대적 손실: 1.0356033
# 스텝 8100에서 판별자 손실: 0.7103709
# 스텝 8100에서 적대적 손실: 0.7803157
# 스텝 8200에서 판별자 손실: 0.694561
# 스텝 8200에서 적대적 손실: 0.8170632
# 스텝 8300에서 판별자 손실: 0.70203304
# 스텝 8300에서 적대적 손실: 0.67859274
# 스텝 8400에서 판별자 손실: 0.69916606
# 스텝 8400에서 적대적 손실: 0.68755066
# 스텝 8500에서 판별자 손실: 0.6836515
# 스텝 8500에서 적대적 손실: 0.7967949
# 스텝 8600에서 판별자 손실: 0.6522809
# 스텝 8600에서 적대적 손실: 0.8549547
# 스텝 8700에서 판별자 손실: 0.67369145
# 스텝 8700에서 적대적 손실: 0.6984723
# 스텝 8800에서 판별자 손실: 0.6716654
# 스텝 8800에서 적대적 손실: 0.80893195
# 스텝 8900에서 판별자 손실: 0.7011934
# 스텝 8900에서 적대적 손실: 0.86674577
# 스텝 9000에서 판별자 손실: 0.6731802
# 스텝 9000에서 적대적 손실: 0.8283526
# 스텝 9100에서 판별자 손실: 0.6920059
# 스텝 9100에서 적대적 손실: 0.8831743
# 스텝 9200에서 판별자 손실: 0.6916548
# 스텝 9200에서 적대적 손실: 0.755504
# 스텝 9300에서 판별자 손실: 0.7117817
# 스텝 9300에서 적대적 손실: 0.9377936
# 스텝 9400에서 판별자 손실: 0.6923071
# 스텝 9400에서 적대적 손실: 1.3385391
# 스텝 9500에서 판별자 손실: 0.6573132
# 스텝 9500에서 적대적 손실: 0.9321238
# 스텝 9600에서 판별자 손실: 0.67844945
# 스텝 9600에서 적대적 손실: 0.8351313
# 스텝 9700에서 판별자 손실: 0.7285064
# 스텝 9700에서 적대적 손실: 0.6035681
# 스텝 9800에서 판별자 손실: 0.6625427
# 스텝 9800에서 적대적 손실: 0.90805835
# 스텝 9900에서 판별자 손실: 0.72981775
# 스텝 9900에서 적대적 손실: 0.92058676
# 스텝 10000에서 판별자 손실: 0.6588336
# 스텝 10000에서 적대적 손실: 0.9142911
# 스텝 10100에서 판별자 손실: 0.64298654
# 스텝 10100에서 적대적 손실: 0.78852874
# 스텝 10200에서 판별자 손실: 0.6983541
# 스텝 10200에서 적대적 손실: 0.77514565
# 스텝 10300에서 판별자 손실: 0.6777376
# 스텝 10300에서 적대적 손실: 0.92823726
# 스텝 10400에서 판별자 손실: 0.6595318
# 스텝 10400에서 적대적 손실: 1.0551918
# 스텝 10500에서 판별자 손실: 0.6719145
# 스텝 10500에서 적대적 손실: 0.740373
# 스텝 10600에서 판별자 손실: 0.67450905
# 스텝 10600에서 적대적 손실: 0.7108587
# 스텝 10700에서 판별자 손실: 0.7350005
# 스텝 10700에서 적대적 손실: 0.92421895
# 스텝 10800에서 판별자 손실: 0.6806755
# 스텝 10800에서 적대적 손실: 0.9583254
# 스텝 10900에서 판별자 손실: 0.69005585
# 스텝 10900에서 적대적 손실: 0.7944807
# 스텝 11000에서 판별자 손실: 0.69045985
# 스텝 11000에서 적대적 손실: 0.7900359
# 스텝 11100에서 판별자 손실: 0.6796621
# 스텝 11100에서 적대적 손실: 0.7607888
# 스텝 11200에서 판별자 손실: 0.697616
# 스텝 11200에서 적대적 손실: 0.77599
# 스텝 11300에서 판별자 손실: 0.6512384
# 스텝 11300에서 적대적 손실: 0.8688615
# 스텝 11400에서 판별자 손실: 0.67185163
# 스텝 11400에서 적대적 손실: 0.78387463
# 스텝 11500에서 판별자 손실: 0.6871116
# 스텝 11500에서 적대적 손실: 0.83877766
# 스텝 11600에서 판별자 손실: 0.6709732
# 스텝 11600에서 적대적 손실: 0.8507725
# 스텝 11700에서 판별자 손실: 0.6997889
# 스텝 11700에서 적대적 손실: 0.7981915
# 스텝 11800에서 판별자 손실: 0.6859711
# 스텝 11800에서 적대적 손실: 0.83411396
# 스텝 11900에서 판별자 손실: 0.67839813
# 스텝 11900에서 적대적 손실: 0.779559
# 스텝 12000에서 판별자 손실: 0.69330394
# 스텝 12000에서 적대적 손실: 1.1102207
# 스텝 12100에서 판별자 손실: 0.7882026
# 스텝 12100에서 적대적 손실: 1.2880396
# 스텝 12200에서 판별자 손실: 0.6854311
# 스텝 12200에서 적대적 손실: 0.7815169
# 스텝 12300에서 판별자 손실: 0.5515511
# 스텝 12300에서 적대적 손실: 0.7962364
# 스텝 12400에서 판별자 손실: 0.6557434
# 스텝 12400에서 적대적 손실: 0.74460846
# 스텝 12500에서 판별자 손실: 0.6575988
# 스텝 12500에서 적대적 손실: 0.8280903
# 스텝 12600에서 판별자 손실: 0.7772442
# 스텝 12600에서 적대적 손실: 1.0688845
# 스텝 12700에서 판별자 손실: 0.75992095
# 스텝 12700에서 적대적 손실: 0.57081175
# 스텝 12800에서 판별자 손실: 0.70282763
# 스텝 12800에서 적대적 손실: 0.7559845
# 스텝 12900에서 판별자 손실: 0.75443757
# 스텝 12900에서 적대적 손실: 0.63396484
# 스텝 13000에서 판별자 손실: 0.6748322
# 스텝 13000에서 적대적 손실: 0.75291336
# 스텝 13100에서 판별자 손실: 0.6966513
# 스텝 13100에서 적대적 손실: 0.9179846
# 스텝 13200에서 판별자 손실: 0.6689359
# 스텝 13200에서 적대적 손실: 0.84236366
# 스텝 13300에서 판별자 손실: 0.7409531
# 스텝 13300에서 적대적 손실: 0.68841964
# 스텝 13400에서 판별자 손실: 0.6839784
# 스텝 13400에서 적대적 손실: 0.7884618
# 스텝 13500에서 판별자 손실: 0.6922431
# 스텝 13500에서 적대적 손실: 0.8624431
# 스텝 13600에서 판별자 손실: 0.6824045
# 스텝 13600에서 적대적 손실: 0.7156783
# 스텝 13700에서 판별자 손실: 0.68234587
# 스텝 13700에서 적대적 손실: 0.9889062
# 스텝 13800에서 판별자 손실: 0.7247659
# 스텝 13800에서 적대적 손실: 0.9064288
# 스텝 13900에서 판별자 손실: 0.7730714
# 스텝 13900에서 적대적 손실: 0.77966493
# 스텝 14000에서 판별자 손실: 0.68604124
# 스텝 14000에서 적대적 손실: 0.79051
# 스텝 14100에서 판별자 손실: 0.65130866
# 스텝 14100에서 적대적 손실: 0.7214658
# 스텝 14200에서 판별자 손실: 0.7023249
# 스텝 14200에서 적대적 손실: 0.6636093
# 스텝 14300에서 판별자 손실: 0.6596669
# 스텝 14300에서 적대적 손실: 0.89969814
# 스텝 14400에서 판별자 손실: 0.7169331
# 스텝 14400에서 적대적 손실: 0.6853266
# 스텝 14500에서 판별자 손실: 0.66923034
# 스텝 14500에서 적대적 손실: 0.9288336
# 스텝 14600에서 판별자 손실: 0.6268156
# 스텝 14600에서 적대적 손실: 1.4845661
# 스텝 14700에서 판별자 손실: 0.6819868
# 스텝 14700에서 적대적 손실: 1.0641348
# 스텝 14800에서 판별자 손실: 0.6707624
# 스텝 14800에서 적대적 손실: 0.9500731
# 스텝 14900에서 판별자 손실: 0.7055699
# 스텝 14900에서 적대적 손실: 0.7559335
# 스텝 15000에서 판별자 손실: 0.6747057
# 스텝 15000에서 적대적 손실: 0.7299905
# 스텝 15100에서 판별자 손실: 0.6805934
# 스텝 15100에서 적대적 손실: 0.90652305
# 스텝 15200에서 판별자 손실: 0.6998173
# 스텝 15200에서 적대적 손실: 0.810754
# 스텝 15300에서 판별자 손실: 0.6841613
# 스텝 15300에서 적대적 손실: 0.84028625
# 스텝 15400에서 판별자 손실: 0.70064414
# 스텝 15400에서 적대적 손실: 0.6653506
# 스텝 15500에서 판별자 손실: 0.67576456
# 스텝 15500에서 적대적 손실: 1.057877
# 스텝 15600에서 판별자 손실: 0.6807313
# 스텝 15600에서 적대적 손실: 0.7523482
# 스텝 15700에서 판별자 손실: 0.6998095
# 스텝 15700에서 적대적 손실: 0.6961807
# 스텝 15800에서 판별자 손실: 0.70225585
# 스텝 15800에서 적대적 손실: 0.75273603
# 스텝 15900에서 판별자 손실: 0.7263849
# 스텝 15900에서 적대적 손실: 0.9845257
# 스텝 16000에서 판별자 손실: 0.6463753
# 스텝 16000에서 적대적 손실: 0.9046211
# 스텝 16100에서 판별자 손실: 0.6928812
# 스텝 16100에서 적대적 손실: 0.76826036
# 스텝 16200에서 판별자 손실: 0.7005202
# 스텝 16200에서 적대적 손실: 0.76681995
# 스텝 16300에서 판별자 손실: 0.67589
# 스텝 16300에서 적대적 손실: 0.8627118
# 스텝 16400에서 판별자 손실: 0.6820261
# 스텝 16400에서 적대적 손실: 0.7621211
# 스텝 16500에서 판별자 손실: 0.6394186
# 스텝 16500에서 적대적 손실: 0.9117115
# 스텝 16600에서 판별자 손실: 0.6933762
# 스텝 16600에서 적대적 손실: 0.88942254
# 스텝 16700에서 판별자 손실: 0.7235519
# 스텝 16700에서 적대적 손실: 2.6928482
# 스텝 16800에서 판별자 손실: 0.6713425
# 스텝 16800에서 적대적 손실: 0.75260943
# 스텝 16900에서 판별자 손실: 0.670331
# 스텝 16900에서 적대적 손실: 0.59328926
# 스텝 17000에서 판별자 손실: 0.6831875
# 스텝 17000에서 적대적 손실: 0.7534815
# 스텝 17100에서 판별자 손실: 0.70690584
# 스텝 17100에서 적대적 손실: 0.77176255
# 스텝 17200에서 판별자 손실: 0.7032599
# 스텝 17200에서 적대적 손실: 0.8073179
# 스텝 17300에서 판별자 손실: 0.6759
# 스텝 17300에서 적대적 손실: 1.0898908
# 스텝 17400에서 판별자 손실: 0.7580365
# 스텝 17400에서 적대적 손실: 0.77958053
# 스텝 17500에서 판별자 손실: 0.71282756
# 스텝 17500에서 적대적 손실: 0.96663827
# 스텝 17600에서 판별자 손실: 0.6669852
# 스텝 17600에서 적대적 손실: 0.77861416
# 스텝 17700에서 판별자 손실: 0.6363692
# 스텝 17700에서 적대적 손실: 0.74426985
# 스텝 17800에서 판별자 손실: 0.768442
# 스텝 17800에서 적대적 손실: 1.0318038
# 스텝 17900에서 판별자 손실: 0.6319114
# 스텝 17900에서 적대적 손실: 0.8287161
# 스텝 18000에서 판별자 손실: 0.6742133
# 스텝 18000에서 적대적 손실: 0.77756405
# 스텝 18100에서 판별자 손실: 0.7053095
# 스텝 18100에서 적대적 손실: 1.1692445
# 스텝 18200에서 판별자 손실: 0.69468033
# 스텝 18200에서 적대적 손실: 0.7873416
# 스텝 18300에서 판별자 손실: 0.71203864
# 스텝 18300에서 적대적 손실: 0.9847166
# 스텝 18400에서 판별자 손실: 0.44418335
# 스텝 18400에서 적대적 손실: 2.3002377
# 스텝 18500에서 판별자 손실: 0.67199075
# 스텝 18500에서 적대적 손실: 0.8724457
# 스텝 18600에서 판별자 손실: 0.6840717
# 스텝 18600에서 적대적 손실: 0.8231964
# 스텝 18700에서 판별자 손실: 0.68460846
# 스텝 18700에서 적대적 손실: 2.0811007
# 스텝 18800에서 판별자 손실: 0.74055004
# 스텝 18800에서 적대적 손실: 0.8999568
# 스텝 18900에서 판별자 손실: 0.7058244
# 스텝 18900에서 적대적 손실: 1.0800304
# 스텝 19000에서 판별자 손실: 0.50469935
# 스텝 19000에서 적대적 손실: 2.3810248
# 스텝 19100에서 판별자 손실: 0.5895936
# 스텝 19100에서 적대적 손실: 1.2094797
# 스텝 19200에서 판별자 손실: 0.15182015
# 스텝 19200에서 적대적 손실: 8.824243
# 스텝 19300에서 판별자 손실: 0.9102987
# 스텝 19300에서 적대적 손실: 1.4288464
# 스텝 19400에서 판별자 손실: 0.5866846
# 스텝 19400에서 적대적 손실: 1.8752234
# 스텝 19500에서 판별자 손실: 0.60168886
# 스텝 19500에서 적대적 손실: 1.0497072
# 스텝 19600에서 판별자 손실: 0.6744619
# 스텝 19600에서 적대적 손실: 2.2259421
# 스텝 19700에서 판별자 손실: 0.6393873
# 스텝 19700에서 적대적 손실: 0.8362442
# 스텝 19800에서 판별자 손실: 0.9028535
# 스텝 19800에서 적대적 손실: 1.8852665
# 스텝 19900에서 판별자 손실: 0.44819045
# 스텝 19900에서 적대적 손실: 2.0110955

# %% [markdown]
# 가짜 이미지 몇개를 출력해 보죠:

# %%
# !cp /content/drive/"My Drive"/lab_colab/soo_gan_generator.h5 .
# from keras.models import load_model
# generator = load_model('./soo_gan_generator.h5')

# %%
import matplotlib.pyplot as plt

# %%
# 잠재 공간에서 랜덤한 포인트를 샘플링합니다
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# 가짜 이미지로 디코딩합니다
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()

# %%
# generator.save('soo_gan_generator.h5')
# !cp -r /content/gan_images /content/drive/"My Drive"/lab_colab/
# !cp /content/gan.h5 /content/drive/"My Drive"/lab_colab/
# !cp /content/soo_gan_generator.h5 /content/drive/"My Drive"/lab_colab/

# %% [markdown]
# 픽셀 경계가 두드러진 개구리처럼 보이는 이미지를 얻었습니다.
